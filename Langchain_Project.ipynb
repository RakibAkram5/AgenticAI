# %% [markdown]
# <a href="https://colab.research.google.com/github/RakibAkram5/AgenticAI/blob/main/Langchain_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-google-genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.2 MB/s eta 0:00:00
# ...

# %%
import langchain_google_genai as genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from google.colab import userdata

# %%
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
GOOGLE_API_KEY
# Out:
# 'AIzaSyAlw9XHqEN3GpPEz4PqA-6ePnfuqzNNsZM'

# %%
model: ChatGoogleGenerativeAI=ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    api_key=GOOGLE_API_KEY,
)

# %%
prompt_template = PromptTemplate(
    input_variables=["question"],
    template="Answer the following question concisely: {question}"
)

# %%
chain = LLMChain(
    llm=model,
    prompt=prompt_template
)
# Out:
# <ipython-input-15-e72a1cd968d9>:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(

# %%
questions = [
    "What is the capital of France?",
    "Who wrote 'Pride and Prejudice'?",
    "What is the speed of light in vacuum?"
]

responses = []

for question in questions:
    response = chain.run({"question": question})
    responses.append(response)
# Out:
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised NotFound: 404 models/gemini-2.0-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-26-ea0e96df99f0> in <cell line: 9>()
#       8
#       9 for question in questions:
# ---> 10     response = chain.run({"question": question})
#      11     responses.append(response)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     180                 warned = True
#     181                 emit_warning()
# --> 182             return wrapped(*args, **kwargs)
#     183
# ...

# %%
for i, response in enumerate(responses, 1):
    print(f"Question {i}: {questions[i-1]}")
    print(f"Response: {response}\n")
    model.temperature = 0.7
model.top_p = 0.9

# %%
creative_prompt_template = PromptTemplate(
    input_variables=["question"],
    template="Be creative and elaborate while answering: {question}"
)

creative_chain = LLMChain(
    llm=model,
    prompt=creative_prompt_template
)

# %%
creative_response = creative_chain.run({"question": "Explain the concept of gravity in simple terms."})
print("Creative Response:\n", creative_response)
# Out:
# WARNING:langchain_google_genai.chat_models:Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised NotFound: 404 models/gemini-2.0-flash is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods..
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-21-e50b5c26eec3> in <cell line: 1>()
# ----> 1 creative_response = creative_chain.run({"question": "Explain the concept of gravity in simple terms."})
#       2 print("Creative Response:\n", creative_response)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     180                 warned = True
#     181                 emit_warning()
# --> 182             return wrapped(*args, **kwargs)
# ...
